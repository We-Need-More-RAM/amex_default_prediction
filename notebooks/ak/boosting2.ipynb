# %%
# %autosave 0
# Out:
# Autosave disabled

# %%
import pandas as pd
import xgboost as xgb
from myfunctions import amex_metric, age_calculator, value_haver, changefinder

# %%
path = '../../data/prepared/'

train_df = pd.read_csv(path + 'train_data.csv')
train_labels = pd.read_csv(path + 'train_labels.csv')
valid_df = pd.read_csv(path + 'val_data.csv')
valid_labels = pd.read_csv(path + 'val_labels.csv')

# %%
train_df = age_calculator(train_df)

train_df.head()
# Out:
#                                          customer_ID       P_2      D_39  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  0.938469  0.001733
# 1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  0.936665  0.005775
# 2  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  0.954180  0.091505
# 3  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  0.960384  0.002455
# 4  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  0.947248  0.002483
#
#         B_1       B_2       R_1       S_3      D_41       B_3  D_42  ...  \
# 0  0.008724  1.006838  0.009228  0.124035  0.008771  0.004709   NaN  ...
# 1  0.004923  1.000653  0.006151  0.126750  0.000798  0.002714   NaN  ...
# 2  0.021655  1.009672  0.006815  0.123977  0.007598  0.009423   NaN  ...
# 3  0.013683  1.002700  0.001373  0.117169  0.000685  0.005531   NaN  ...
# 4  0.015193  1.000727  0.007605  0.117325  0.004653  0.009312   NaN  ...
#
#    D_137  D_138     D_139     D_140     D_141  D_142     D_143     D_144  \
# ...

# %%
null_count_columns = ['D_42', 'D_49', 'D_134', 'D_135', 'D_136', 'D_137', 'D_138']
change_over_time_columns = ['D_55', 'B_16', 'B_20']

# %%
train_final = value_haver(train_df, null_count_columns)

train_final.head()
# Out:
#                                                     D_42_has_value  \
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...             0.0
# 0005ef1480ffe4f0e5908eae07db8e05f2e705bca6a57db...             0.0
# 0005f2ab0cc352cd64eac9e60b981ed8c3289d20fa5fcef...             0.0
# 0007ee1ac8edb6be588c6c8a158d2268e3228c49cf52773...             0.0
# 0008ef32824d3067b4d8ab70e7c79fa04c808f4d99194fe...             0.0
#
#                                                     D_49_has_value  \
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...             0.0
# 0005ef1480ffe4f0e5908eae07db8e05f2e705bca6a57db...             0.0
# 0005f2ab0cc352cd64eac9e60b981ed8c3289d20fa5fcef...             0.0
# 0007ee1ac8edb6be588c6c8a158d2268e3228c49cf52773...             1.0
# 0008ef32824d3067b4d8ab70e7c79fa04c808f4d99194fe...             0.0
#
#                                                     D_134_has_value  \
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...              0.0
# ...

# %%
train_final = changefinder(train_final, train_df, change_over_time_columns)

train_final.head()
# Out:
#                                                     D_42_has_value  \
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...             0.0
# 0005ef1480ffe4f0e5908eae07db8e05f2e705bca6a57db...             0.0
# 0005f2ab0cc352cd64eac9e60b981ed8c3289d20fa5fcef...             0.0
# 0007ee1ac8edb6be588c6c8a158d2268e3228c49cf52773...             0.0
# 0008ef32824d3067b4d8ab70e7c79fa04c808f4d99194fe...             0.0
#
#                                                     D_49_has_value  \
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...             0.0
# 0005ef1480ffe4f0e5908eae07db8e05f2e705bca6a57db...             0.0
# 0005f2ab0cc352cd64eac9e60b981ed8c3289d20fa5fcef...             0.0
# 0007ee1ac8edb6be588c6c8a158d2268e3228c49cf52773...             1.0
# 0008ef32824d3067b4d8ab70e7c79fa04c808f4d99194fe...             0.0
#
#                                                     D_134_has_value  \
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...              0.0
# ...
